# %%
# Convert date column
import pandas as pd
df = pd.read_csv('../data/Retail_Sales_Data_Unlox.csv')
df['Date'] = pd.to_datetime(df['Date'])
df = df.sort_values('Date')

# Create time features
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day
df['Weekday'] = df['Date'].dt.day_name()

# Create revenue if not present
if 'Revenue' not in df.columns:
    df['Revenue'] = df['Quantity'] * df['Price']

# Handle missing / outliers
df.fillna(method='ffill', inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10156\1669989008.py:18: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)
